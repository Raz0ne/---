# %% [markdown]
# ![image.png](attachment:97175271-74ae-432b-aced-8d46ee67e37f.png)

# %% [markdown]
# ![image.png](attachment:987d84df-f1ad-4e2f-9a17-350f247b3ee7.png)

# %% [markdown]
# ![image.png](attachment:c369566b-2539-4d91-a011-7d950f0ffffa.png)

# %% [markdown]
# ![image.png](attachment:502aad41-41b5-4a0f-9a2b-92310334e656.png)

# %%
response_times = [150, 130, 140, 160, 180, 170, 190, 200, 175, 165]

# %%
import statsmodels.stats.api as sms
t = sms.DescrStatsW(response_times)
t.tconfint_mean(alpha=0.05, alternative='two-sided')
# Out:
# (150.38182928831, 181.61817071169)

# %% [markdown]
# 150,38
