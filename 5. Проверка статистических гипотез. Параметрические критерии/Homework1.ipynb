# %% [markdown]
# ![image.png](attachment:28ff75eb-a733-4312-b53d-393c93690650.png)

# %% [markdown]
# ![image.png](attachment:f98f346d-af72-4a31-a935-1c5cd92bce30.png)

# %% [markdown]
# ![image.png](attachment:b8a909db-21ba-4ec3-8132-d27cf75b74d1.png)

# %% [markdown]
# ![image.png](attachment:7fecb1b6-13ec-406c-a10b-96ec405da1ab.png)

# %% [markdown]
# ![image.png](attachment:3b3934e7-c5d7-4b6e-ae98-f240e5630615.png)

# %% [markdown]
# ![image.png](attachment:13e68864-cc43-43c3-840d-bf66ed7dbb3b.png)

# %% [markdown]
# ![image.png](attachment:89c49bc4-5652-4326-ada0-15c1a5cdbb68.png)

# %%
from scipy import stats

# %%
algorithm_a_times = [3.2, 5.1, 4.3, 6.7, 7.9, 4.8, 5.6, 6.2, 5.9]
algorithm_b_times = [2.9, 4.5, 6.1, 5.8, 4.2, 5.3, 4.7, 6.5, 6.8]

stats.mannwhitneyu(algorithm_a_times, algorithm_b_times)
# Out:
# MannwhitneyuResult(statistic=46.0, pvalue=0.6588432549492806)

# %% [markdown]
# 46,0

# %% [markdown]
# ![image.png](attachment:6b04aef9-ed0f-404f-8986-0e78235e55e6.png)

# %% [markdown]
# 0,66

# %% [markdown]
# ![image.png](attachment:66668bb8-e48e-4a43-a628-d749fb388e36.png)

# %% [markdown]
# ![image.png](attachment:9888a0fe-d313-4a2f-807b-5fe6a34b0fdc.png)
